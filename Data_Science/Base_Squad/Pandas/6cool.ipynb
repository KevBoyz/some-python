# %%
import pandas as pd

# %%
df = pd.read_csv(r'../../Projects\04-Titanic\assets\train.csv', index_col=3)

# %%
filtro = df['Survived'] == 1
df[filtro == False]
# Out:
#                                           PassengerId  Survived  Pclass  \
# Name
# Braund, Mr. Owen Harris                             1         0       3
# Allen, Mr. William Henry                            5         0       3
# Moran, Mr. James                                    6         0       3
# McCarthy, Mr. Timothy J                             7         0       1
# Palsson, Master. Gosta Leonard                      8         0       3
# ...                                               ...       ...     ...
# Sutehall, Mr. Henry Jr                            885         0       3
# Rice, Mrs. William (Margaret Norton)              886         0       3
# Montvila, Rev. Juozas                             887         0       2
# Johnston, Miss. Catherine Helen "Carrie"          889         0       3
# Dooley, Mr. Patrick                               891         0       3
#
#                                              Sex   Age  SibSp  Parch  \
# Name
# ...

# %%
df.loc['Montvila, Rev. Juozas', 'Age']
#df.iloc[10, 3]
# Out:
# np.float64(27.0)

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='pie')
# Out:
# <Axes: ylabel='Survived'>

# %%
df['Sex'].map({'male': 0, 'female': 1})
# Out:
# Name
# Braund, Mr. Owen Harris                                0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
# Allen, Mr. William Henry                               0
#                                                       ..
# Montvila, Rev. Juozas                                  0
# Graham, Miss. Margaret Edith                           1
# Johnston, Miss. Catherine Helen "Carrie"               1
# Behr, Mr. Karl Howell                                  0
# Dooley, Mr. Patrick                                    0
# Name: Sex, Length: 891, dtype: int64

# %%
df[df['Name'] == 'd'].empty
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Windows11\AppData\Local\pypoetry\Cache\virtualenvs\data-science-RaKH72jV-py3.13\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ...

# %%
df.rename(columns={'Age': 'kkkkk', 'Sex': 'jjj'})
# Out:
# C:\Users\Windows11\AppData\Local\Temp\ipykernel_5268\1015521126.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.colums = [c.lower() for c in df.columns]

# %%
df.where(df['Age'] > 24).dropna()  # mask é o inverso de where
# Substitui tudo por nan
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          2.0       1.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                4.0       1.0
# McCarthy, Mr. Timothy J                                     7.0       0.0
# Bonnell, Miss. Elizabeth                                   12.0       1.0
# Beesley, Mr. Lawrence                                      22.0       1.0
# ...                                                         ...       ...
# Roebling, Mr. Washington Augustus II                      868.0       0.0
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          872.0       1.0
# Carlsson, Mr. Frans Olof                                  873.0       0.0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)             880.0       1.0
# Behr, Mr. Karl Howell                                     890.0       1.0
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df.set_index(['Sex', 'Age'])
# Out:
#              PassengerId  Survived  Pclass  SibSp  Parch            Ticket  \
# Sex    Age
# male   22.0            1         0       3      1      0         A/5 21171
# female 38.0            2         1       1      1      0          PC 17599
#        26.0            3         1       3      0      0  STON/O2. 3101282
#        35.0            4         1       1      1      0            113803
# male   35.0            5         0       3      0      0            373450
# ...                  ...       ...     ...    ...    ...               ...
#        27.0          887         0       2      0      0            211536
# female 19.0          888         1       1      0      0            112053
#        NaN           889         0       3      1      2        W./C. 6607
# male   26.0          890         1       1      0      0            111369
#        32.0          891         0       3      0      0            370376
#
#                 Fare Cabin Embarked
# Sex    Age
# ...

# %%
# df.loc['male', 22.0]

# %% [markdown]
# Concat une df (mesma estrutura), merge enriquece um (novas colunas) por meio de um indicie
