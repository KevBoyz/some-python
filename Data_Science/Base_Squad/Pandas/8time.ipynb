# %%
import pandas as pd

# %%
pd.Timestamp(2019, 12, 20, 12, 41)
# Out:
# Timestamp('2019-12-20 12:41:00')

# %%
pd.Period('1/2016') - 3
# Out:
# Period('2015-10', 'M')

# %% [markdown]
# Pandas consegue padronizar os estilos de data mais bizarros

# %%
# Out:
# Period('2016-01', 'M')
